# %%
import tensorflow as tf
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np 
import torch  
from ultralytics import YOLO

# %%
# model = YOLO("yolov8n-seg.yaml")  # build a new model from scratch
# model

# %%
# results = model.train(data="./data.yaml", epochs=50)

# %%
model = YOLO("./runs/segment/train2/weights/best.pt")  # build a new model from scratch

# %%
img = './Documents/Documents/Official document/img/0029.jpg'
img2 = './Documents/Documents/Official document/img/004.jpg'
results1 = model(img) 
results2 = model(img2) # predict on an image
# Out:
# image 1/1 D:\Joe13\Paper detection\Documents\Documents\Official document\img\0029.jpg: 640x480 1 document, 166.6ms
# Speed: 7.5ms preprocess, 166.6ms inference, 25.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 D:\Joe13\Paper detection\Documents\Documents\Official document\img\004.jpg: 640x480 1 document, 194.6ms
# Speed: 4.1ms preprocess, 194.6ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 480)

# %%
for result in results1:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    result.save_crop('./')
    result.show()

# %%
for result in results2:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    result.save_crop('./')
    result.show()

# %%
from ultralytics import YOLO

# Load the trained YOLOv8 model
model = YOLO("./runs/segment/train/weights/best.pt")

# Set the confidence threshold for detection
model.conf = 0.5
img = 'D:/Joe13/Paper detection/Documents/Documents/Official document/img'

# Perform object detection on an image
results = model(img)
# Out:
# image 1/842 D:\Joe13\Paper detection\Documents\Documents\Official document\img\001.jpg: 640x480 (no detections), 123.2ms
# image 2/842 D:\Joe13\Paper detection\Documents\Documents\Official document\img\0010.jpg: 640x480 1 document, 104.2ms
# image 3/842 D:\Joe13\Paper detection\Documents\Documents\Official document\img\00100.jpg: 640x384 (no detections), 173.4ms
# image 4/842 D:\Joe13\Paper detection\Documents\Documents\Official document\img\00101.jpg: 640x480 4 documents, 108.7ms
# image 5/842 D:\Joe13\Paper detection\Documents\Documents\Official document\img\00102.jpg: 448x640 1 document, 100.0ms
# image 6/842 D:\Joe13\Paper detection\Documents\Documents\Official document\img\00103.jpg: 640x480 (no detections), 100.4ms
# image 7/842 D:\Joe13\Paper detection\Documents\Documents\Official document\img\00104.jpg: 640x384 2 documents, 154.2ms
# image 8/842 D:\Joe13\Paper detection\Documents\Documents\Official document\img\00105.jpg: 384x640 1 document, 92.3ms
# ...

# %%
import cv2

# Load image
img_path = './Documents/Documents/Official document/img/004.jpg'

folder_path = 'D:/Joe13/Paper detection/Documents/Documents/National Id/train/images/'
img = cv2.imread(img_path)

# Load model
model_path = './runs/segment/train2/weights/best.pt'
model = YOLO(model_path)  # Assuming YOLO is imported and initialized correctly

# Run model inference
results = model(folder_path, save = True)
# Out:
# image 1/393 D:\Joe13\Paper detection\Documents\Documents\National Id\train\images\file100_png.rf.224687aad3de9e25b6bb48cceddcd20e.jpg: 640x640 1 document, 213.6ms
# image 2/393 D:\Joe13\Paper detection\Documents\Documents\National Id\train\images\file101_png.rf.764e3cd4421285f001a80437929e8073.jpg: 640x640 1 document, 108.4ms
# image 3/393 D:\Joe13\Paper detection\Documents\Documents\National Id\train\images\file102_png.rf.36678dd553b636f159e3ce93fdf79857.jpg: 640x640 1 document, 197.8ms
# image 4/393 D:\Joe13\Paper detection\Documents\Documents\National Id\train\images\file103_png.rf.bd41c786f09268c6ae83f004e563948a.jpg: 640x640 1 document, 236.3ms
# image 5/393 D:\Joe13\Paper detection\Documents\Documents\National Id\train\images\file104_png.rf.235d56272e6300405e1951015fa0a1a5.jpg: 640x640 1 document, 214.2ms
# image 6/393 D:\Joe13\Paper detection\Documents\Documents\National Id\train\images\file105_png.rf.1426e4367f37031e63d282a42eff7e5b.jpg: 640x640 1 document, 171.6ms
# ...
